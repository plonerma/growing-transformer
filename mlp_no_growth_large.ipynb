# %% [markdown]
# # Without any growth

# %%
import torch
from sandbox import SimpleModel, toy_data, experiment_series, eval_series
from pathlib import Path

# %%
model_params = (1, 1, 8, 10, 10)

eps = 1e-4
num_kept_neurons = 2
lr=0.005
runs=10

# %%
series = experiment_series(model_params, runs=runs, grow=None, lr=lr)
# Out:
# #0: loss: 0.021972913295030594 - size: 209
# #1: loss: 0.02158816158771515 - size: 209
# #2: loss: 0.021540813148021698 - size: 209
# #3: loss: 0.0220185536891222 - size: 209
# #4: loss: 0.022255534306168556 - size: 209
# #5: loss: 0.02147575095295906 - size: 209
# #6: loss: 0.025696992874145508 - size: 209
# #7: loss: 0.02120988443493843 - size: 209
# #8: loss: 0.019121278077363968 - size: 209
# #9: loss: 0.026048831641674042 - size: 209

# %%
eval_series(series)

# %%
d = Path("results")
d.mkdir(parents=True, exist_ok=True)

torch.save(series, d / 'no_growth_large.pt')
