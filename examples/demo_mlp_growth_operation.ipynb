# %%
import torch
import numpy as np
from sandbox import SimpleModel, toy_data
import copy
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Simple Model

# %%
torch.manual_seed(0)

# keep same initialization
original_model = SimpleModel(1, 1, 4, 6, 6)

# %%
model = original_model
optim = torch.optim.SGD(model.parameters(), lr=0.1)
criterion = torch.nn.MSELoss()
losses = list()

num_batches = 200

for epoch in range(50):
    loss_sum = 0
    for batch in range(num_batches):
        train_x, train_y = toy_data()
        optim.zero_grad()
        y = model(train_x)
        loss = criterion(y, train_y)
        loss_sum += loss.data
        loss.backward()
        optim.step()
        
    losses.append(loss_sum / num_batches)


print(f"loss: {loss.data} - size: {sum(p.numel() for p in model.parameters())}")

plt.subplots(figsize=(10, 4))
plt.plot(losses)
plt.gca().xaxis.grid(True)
plt.show()
# Out:
# loss: 0.04984508827328682 - size: 77

# %%
plt.subplots(figsize=(12, 8))

model.eval()

train_x, train_y = toy_data()

x = torch.linspace(-5, 5, 100)[:, None]



y = model(x).detach().numpy()
x = x.detach().numpy()
plt.plot(x, y, c='tab:orange')

plt.scatter(train_x.detach(), train_y.detach(), marker='+')
plt.ylim([-1, 1])
plt.show()

# %% [markdown]
# # Growing the model

# %% [markdown]
# ## Influence of new neuron (with different inits)

# %%
cmap = plt.get_cmap("viridis")
vmax = 2

torch.manual_seed(0)


plt.subplots(figsize=(12, 8))
for step in np.linspace(0, vmax, 20)[::-1]:
    x = torch.linspace(-5, 5, 100)[:, None]
    
    model = copy.deepcopy(original_model)
    
    if step is not None:
        model.grow(num_novel=4, step_size=step, split=False)

    y = model(x).detach().numpy()
    x = x.detach().numpy()
    plt.plot(x, y, c=cmap(1-step/vmax))

plt.scatter(train_x.detach(), train_y.detach(), marker='x')
plt.ylim([-1, 1])
plt.show()

# %% [markdown]
# ## Influence of neuron split noise

# %%
torch.manual_seed(0)
vmax = 2

plt.subplots(figsize=(12, 8))

for step in np.linspace(0, vmax, 20)[::-1]:
    x = torch.linspace(-5, 5, 100)[:, None]
    
    model = copy.deepcopy(original_model)
    if step is not None:
        model.grow(split=True, num_novel=0, step_size=step)
        
        
    y = model(x).detach().numpy()
    x = x.detach().numpy()
    plt.plot(x, y, c=cmap(1-step/vmax))

plt.scatter(train_x.detach(), train_y.detach(), marker='x')
plt.ylim([-1, 1])
plt.show()
