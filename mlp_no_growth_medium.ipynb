# %% [markdown]
# # Without any growth

# %%
import torch
from sandbox import SimpleModel, toy_data, experiment_series, eval_series
from pathlib import Path

# %%
model_params = (1, 1, 8, 6, 6)

eps = 1e-4
num_kept_neurons = 2
lr=0.005
runs=10

# %%
series = experiment_series(model_params, runs=runs, grow=None, lr=lr)
# Out:
# #0: loss: 0.02259623259305954 - size: 129
# #1: loss: 0.026050422340631485 - size: 129
# #2: loss: 0.02736091800034046 - size: 129
# #3: loss: 0.02687172219157219 - size: 129
# #4: loss: 0.02309740148484707 - size: 129
# #5: loss: 0.024855343624949455 - size: 129
# #6: loss: 0.028457047417759895 - size: 129
# #7: loss: 0.0296311192214489 - size: 129
# #8: loss: 0.02834949642419815 - size: 129
# #9: loss: 0.02497117966413498 - size: 129

# %%
eval_series(series)

# %%
d = Path("results")
d.mkdir(parents=True, exist_ok=True)

torch.save(series, d / 'no_growth_medium.pt')
