# %% [markdown]
# # Without any growth

# %%
import torch
from sandbox import SimpleModel, toy_data, experiment_series, eval_series
from pathlib import Path

# %%
model_params = (1, 1, 8, 2, 2)

eps = 1e-4
num_kept_neurons = 2
lr=0.005
runs=10

# %%
series = experiment_series(model_params, runs=runs, grow=None, lr=lr)
# Out:
# #0: loss: 0.07523774355649948 - size: 49
# #1: loss: 0.17799369990825653 - size: 49
# #2: loss: 0.2652992010116577 - size: 49
# #3: loss: 0.26384010910987854 - size: 49
# #4: loss: 0.1867121458053589 - size: 49
# #5: loss: 0.2668992280960083 - size: 49
# #6: loss: 0.27042144536972046 - size: 49
# #7: loss: 0.17673051357269287 - size: 49
# #8: loss: 0.18717986345291138 - size: 49
# #9: loss: 0.19612140953540802 - size: 49

# %%
eval_series(series)

# %%
d = Path("results")
d.mkdir(parents=True, exist_ok=True)

torch.save(series, d / 'no_growth_small.pt')
