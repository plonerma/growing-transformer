# %% [markdown]
# # Without any growth

# %%
import torch
from sandbox import SimpleModel, toy_data, experiment_series, eval_series
from pathlib import Path

# %%
model_params = (1, 1, 8, 2, 2)

eps = 1e-4
num_kept_neurons = 2
lr=0.005
runs=10

# %%
series = experiment_series(model_params, runs=runs, grow=None, lr=lr)
# Out:
# #0: loss: 0.029852967709302902 - size: 49
# #1: loss: 0.17726634442806244 - size: 49
# #2: loss: 0.1809495985507965 - size: 49
# #3: loss: 0.03116130270063877 - size: 49
# #4: loss: 0.18611252307891846 - size: 49
# #5: loss: 0.33393189311027527 - size: 49
# #6: loss: 0.18660776317119598 - size: 49
# #7: loss: 0.187836155295372 - size: 49
# #8: loss: 0.0555320642888546 - size: 49
# #9: loss: 0.02916743978857994 - size: 49

# %%
eval_series(series)

# %%
d = Path("results")
d.mkdir(parents=True, exist_ok=True)

torch.save(series, d / 'no_growth_small.pt')
