# %% [markdown]
# # Without any growth

# %%
import torch
from sandbox import SimpleModel, toy_data, experiment_series, eval_series
import copy
import matplotlib.pyplot as plt

# %%
model_params = (1, 1, 8, 2, 2)

eps = 1e-4
num_kept_neurons = 2
lr=0.005
runs=10

# %%
results = experiment_series(model_params, runs=runs, grow=None, lr=lr)
# Out:
# #0: loss: 0.28550034761428833 - size: 49
# #1: loss: 0.4114319980144501 - size: 49
# #2: loss: 0.4089781641960144 - size: 49
# #3: loss: 0.40661343932151794 - size: 49
# #4: loss: 0.41125255823135376 - size: 49
# #5: loss: 0.41123849153518677 - size: 49
# #6: loss: 0.4173857569694519 - size: 49
# #7: loss: 0.26487764716148376 - size: 49
# #8: loss: 0.2830350399017334 - size: 49
# #9: loss: 0.5206261873245239 - size: 49

# %%
eval_series(results)
